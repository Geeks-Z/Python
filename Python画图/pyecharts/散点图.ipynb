# %%
from pyecharts import Scatter
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\Repositories\Python\Python画图\pyecharts\散点图.ipynb 单元格 1 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/Repositories/Python/Python%E7%94%BB%E5%9B%BE/pyecharts/%E6%95%A3%E7%82%B9%E5%9B%BE.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from pyecharts import Scatter
#
# File c:\SoftWare\Code\IDE\Anaconda3\envs\torch_hwzhao\lib\site-packages\pyecharts\__init__.py:2
#       1 # basic Charts
# ----> 2 from ..charts.basic_charts.bar import Bar
#       3 from ..charts.basic_charts.bmap import BMap
#       4 from ..charts.basic_charts.boxplot import Boxplot
#
# ValueError: attempted relative import beyond top-level package

# %%
v1 = [10, 20, 30, 40, 50, 60]
v2 = [10, 20, 30, 40, 50, 60]
scatter = Scatter("散点图示例")
scatter.add("A", v1, v2)
scatter.add("B", v1[::-1], v2)
scatter.render()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# f:\Repositories\Python\Python画图\pyecharts\散点图.ipynb 单元格 1 line 1
# ----> <a href='vscode-notebook-cell:/f%3A/Repositories/Python/Python%E7%94%BB%E5%9B%BE/pyecharts/%E6%95%A3%E7%82%B9%E5%9B%BE.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from pyecharts import Scatter
#       <a href='vscode-notebook-cell:/f%3A/Repositories/Python/Python%E7%94%BB%E5%9B%BE/pyecharts/%E6%95%A3%E7%82%B9%E5%9B%BE.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> v1 = [10, 20, 30, 40, 50, 60]
#       <a href='vscode-notebook-cell:/f%3A/Repositories/Python/Python%E7%94%BB%E5%9B%BE/pyecharts/%E6%95%A3%E7%82%B9%E5%9B%BE.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> v2 = [10, 20, 30, 40, 50, 60]
#
# ImportError: cannot import name 'Scatter' from 'pyecharts' (c:\SoftWare\Code\IDE\Anaconda3\envs\torch_hwzhao\lib\site-packages\pyecharts\__init__.py)
